# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from dateutil import parser
from PIL import Image

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Quito_USFQ = pd.read_csv('/content/drive/MyDrive/TAMUCC-SEU NASA Pandora-AERONET Project/SEU AERONET/Data/ecuador.csv')

# %%
Quito_USFQ.head()
# Out:
#          Site Date(dd:mm:yyyy) Time(hh:mm:ss)  Day_of_Year  \
# 0  Quito_USFQ      0.863622685       13:36:41          293
# 1  Quito_USFQ       0.36431713       12:01:23          312
# 2  Quito_USFQ       0.36431713       12:31:49          312
# 3  Quito_USFQ       0.36431713       13:14:17          312
# 4  Quito_USFQ       0.36431713       13:40:54          312
#
#    Day_of_Year(Fraction)      0.05  0.065604  0.086077  0.112939  0.148184  \
# 0             293.567141  0.000188  0.000993  0.003310  0.007078  0.010119
# 1             312.500961  0.000326  0.001951  0.007590  0.019423  0.031640
# 2             312.522095  0.000247  0.001756  0.008046  0.022398  0.034154
# 3             312.551586  0.000219  0.003271  0.015587  0.027889  0.029324
# 4             312.570069  0.000210  0.001369  0.005774  0.015377  0.024021
#
#    ...  If_Retrieval_is_L2(without_L2_0.4_AOD_440_threshold)  If_AOD_is_L2  \
# 0  ...                                                  1                1
# ...

# %%
Quito_USFQ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 611 entries, 0 to 610
# Data columns (total 63 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Site                                                       611 non-null    object
#  1   Date(dd:mm:yyyy)                                           611 non-null    object
#  2   Time(hh:mm:ss)                                             611 non-null    object
#  3   Day_of_Year                                                611 non-null    int64
#  4   Day_of_Year(Fraction)                                      611 non-null    float64
#  5   0.05                                                       611 non-null    float64
#  6   0.065604                                                   611 non-null    float64
# ...

# %%
import matplotlib.pyplot as plt

size_distribution_column = 'Inflection_Radius_of_Size_Distribution(um)'

size_distribution_data = Quito_USFQ[size_distribution_column]

plt.figure(figsize=(10, 6))
plt.scatter(size_distribution_data.index, size_distribution_data)
plt.title('Size Distribution')
plt.xlabel('Index')
plt.ylabel('Concentration')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()
